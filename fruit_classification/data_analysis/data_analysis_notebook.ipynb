# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
df = pd.read_excel("data/archive/Date_Fruit_Datasets/Date_Fruit_Datasets.xlsx")
df.head()
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0  422163   2378.908    837.8484    645.6693        0.6373  733.1539
# 1  338136   2085.144    723.8198    595.2073        0.5690  656.1464
# 2  526843   2647.394    940.7379    715.3638        0.6494  819.0222
# 3  416063   2351.210    827.9804    645.2988        0.6266  727.8378
# 4  347562   2160.354    763.9877    582.8359        0.6465  665.2291
#
#    SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0    0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1    0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2    0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3    0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4    0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
#
#    KurtosisRB    EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  ALLdaub4RG  \
# ...

# %%
df.shape
# Out:
# (898, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           898 non-null    int64
#  1   PERIMETER      898 non-null    float64
#  2   MAJOR_AXIS     898 non-null    float64
#  3   MINOR_AXIS     898 non-null    float64
#  4   ECCENTRICITY   898 non-null    float64
#  5   EQDIASQ        898 non-null    float64
#  6   SOLIDITY       898 non-null    float64
#  7   CONVEX_AREA    898 non-null    int64
#  8   EXTENT         898 non-null    float64
#  9   ASPECT_RATIO   898 non-null    float64
#  10  ROUNDNESS      898 non-null    float64
#  11  COMPACTNESS    898 non-null    float64
#  12  SHAPEFACTOR_1  898 non-null    float64
#  13  SHAPEFACTOR_2  898 non-null    float64
#  14  SHAPEFACTOR_3  898 non-null    float64
#  15  SHAPEFACTOR_4  898 non-null    float64
#  16  MeanRR         898 non-null    float64
# ...

# %%
pd.set_option('display.max_columns', None)

df.describe()
# Out:
#                 AREA    PERIMETER   MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# count     898.000000   898.000000   898.000000  898.000000    898.000000
# mean   298295.207127  2057.660953   750.811994  495.872785      0.737468
# std    107245.205337   410.012459   144.059326  114.268917      0.088727
# min      1987.000000   911.828000   336.722700    2.283200      0.344800
# 25%    206948.000000  1726.091500   641.068650  404.684375      0.685625
# 50%    319833.000000  2196.345450   791.363400  495.054850      0.754700
# 75%    382573.000000  2389.716575   858.633750  589.031700      0.802150
# max    546063.000000  2811.997100  1222.723000  766.453600      1.000000
#
#           EQDIASQ    SOLIDITY    CONVEX_AREA      EXTENT  ASPECT_RATIO  \
# count  898.000000  898.000000     898.000000  898.000000    898.000000
# mean   604.577938    0.981840  303845.592428    0.736267      2.131102
# std    119.593888    0.018157  108815.656947    0.053745     17.820778
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# DOKOL     204
# SAFAVI    199
# ROTANA    166
# DEGLET     98
# SOGAY      94
# IRAQI      72
# BERHI      65
# Name: count, dtype: int64

# %%
labels = df["Class"]
feature_df = df.drop(columns=["Class"])
feature_df.shape
# Out:
# (898, 34)

# %%
plt.bar(labels.unique(), labels.value_counts())
# Out:
# <BarContainer object of 7 artists>

# %%
std_df = (feature_df - feature_df.mean()) / feature_df.std()

# %%
fig, axs = plt.subplots(7, 5, figsize=(30, 30))

for index, column in enumerate(std_df.columns):
    row = index // 5
    col = index % 5
    axs[row, col].hist(std_df[column])
    axs[row, col].set_title(column)

fig.show()
# Out:
# C:\Users\Andrei Bejan\AppData\Local\Temp\ipykernel_25024\2722130055.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
pca = PCA(n_components = 2)
points = pca.fit_transform(std_df)
points.shape
# Out:
# (898, 2)

# %%
tsne = TSNE(n_components = 2)
points = tsne.fit_transform(std_df)
points.shape
# Out:
# (898, 2)

# %%
colors, _ = pd.factorize(labels)

# %%
plt.scatter(points[:, 0], points[:, 1], c = colors)

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(feature_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(feature_df.corr(method='spearman'), annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(feature_df.corr(method='kendall'), annot=True)
# Out:
# <Axes: >

# %%
oh_encoded_labels = pd.get_dummies(labels, dtype=int)
oh_encoded_labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Andrei Bejan\Desktop\Kaggle\Kaggle\fruit_classification\data_analysis_notebook.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Andrei%20Bejan/Desktop/Kaggle/Kaggle/fruit_classification/data_analysis_notebook.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> oh_encoded_labels = pd.get_dummies(labels, dtype=int)
#       <a href='vscode-notebook-cell:/c%3A/Users/Andrei%20Bejan/Desktop/Kaggle/Kaggle/fruit_classification/data_analysis_notebook.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> oh_encoded_labels
#
# NameError: name 'pd' is not defined

# %%
plt.scatter(feature_df["ALLdaub4RR"], feature_df["ALLdaub4RG"]) # only one should remain bc of high linear correlation

# %%
plt.scatter(feature_df["AREA"], feature_df["MAJOR_AXIS"])

# %%
plt.scatter(feature_df["ECCENTRICITY"], feature_df["ASPECT_RATIO"]) # only one should remain bc of high linear correlation
